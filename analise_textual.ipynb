# %%
import os
import ssl
import httpx
from dotenv import load_dotenv
from groq import Groq

load_dotenv()

def criar_cliente_groq_ssl_desabilitado():
# Criar um contexto SSL que não verifica certificados
    ssl_context = ssl.create_default_context()
    ssl_context.check_hostname = False
    ssl_context.verify_mode = ssl.CERT_NONE

    http_client = httpx.Client(verify=False)

    client = Groq(
        api_key=os.getenv('GROQ_API'),
        http_client=http_client
    )

    return client

# Testar o cliente
client = criar_cliente_groq_ssl_desabilitado()
print("cliente criado com sucesso!")
# Out:
# cliente criado com sucesso!

# %% [markdown]
# ### Análise Textual 1 - Cores e Ambientes

# %%
system_prompt = """
Você é um especialista em análise visual. Dada uma descreição de imagem, identifique:
1. Paleta de cores dominante
2. Clima ou atmosfera sugerida
3. Elementos de cenário
"""

user_prompt = """
Descrição:

"Uma montanha ao pôr do sol, céu en tons alaranjados, lua cheia grande,
um pai e um filho andando de bicicleta na montanha."
"""

response = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.6
)
print(f"Resposta {response.choices[0].message.content}\n")
# Out:
# Resposta **1. Paleta de cores dominante**
# - **Laranja/âmbar**: predominante no céu ao pôr‑do‑sol, criando um fundo quente e vibrante.
# - **Vermelho‑alaranjado e dourado**: reflexos nas nuvens e nas encostas da montanha.
# - **Azul‑escuro / violeta profundo**: surgindo nas áreas de sombra da montanha e no horizonte, contrastando com o laranja.
# - **Branco prateado**: da lua cheia, que se destaca como ponto de luz frio contra o céu quente.
# - **Verde‑escuro / marrom**: nas áreas de vegetação e rocha da montanha, porém menos saturados, servindo de suporte à paleta quente.
#
# **2. Clima ou atmosfera sugerida**
# - **Atmosfera de fim de tarde serena, porém dramática**: o pôr‑do‑sol traz calor e tranquilidade, enquanto a presença da lua cheia adiciona um toque de mistério e magia.
# - **Sensação de calmaria com leve frescor**: o ar nas montanhas costuma ser mais fresco ao entardecer; a combinação de luz quente e luz lunar cria um clima de “crepúsculo duplo”.
# ...

# %% [markdown]
# ### Análise Textual 2 - Objetos e Elementos

# %%
system_prompt = """
Você é um analista de imagens em textos. Identifique:
1. Objetos principais
2. Relação entre eles
3. Elementos secundários
"""

user_prompt = """
Descrição:

"Uma montanha ao pôr do sol, céu en tons alaranjados, lua cheia grande,
um pai e um filho andando de bicicleta na montanha."
"""

response = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.6
)
print(f"Resposta {response.choices[0].message.content}\n")
# Out:
# Resposta **1. Objetos principais**
# - Montanha (cenário natural).
# - Céu ao pôr‑do‑sol (tons alaranjados).
# - Lua cheia (grande, visível no céu).
# - Pai (adulto).
# - Filho (criança).
# - Bicicleta (usada pelos dois).
#
# **2. Relação entre eles**
# - **Pai e filho** estão juntos, compartilhando a mesma atividade: ambos pedalam **na mesma bicicleta** (ou cada um em sua bicicleta, dependendo da interpretação).
# - Eles estão **sobre a encosta da montanha**, usando a bicicleta como meio de locomoção.
# - A **montanha** serve de plano de fundo e de superfície onde a ação ocorre.
# - O **céu ao pôr‑do‑sol** ilumina a cena, criando uma atmosfera quente que envolve a montanha, o casal e a bicicleta.
# - A **lua cheia** está posicionada no céu, contrastando com a luz alaranjada do pôr‑do‑sol e acrescentando profundidade ao ambiente.
#
# **3. Elementos secundários**
# - Tonalidade alaranjada do céu (reflexos nas nuvens e na superfície da montanha).
# ...

# %% [markdown]
# ### Análise Textual 3 - Anãlise Simbólica

# %%
system_prompt = """
Você é um especialista em semiótica visual. Identifique:
1. Significados simbólicios dos elemntos
2. Possíveis metáforas
3. Impacto emocional no observador
"""

user_prompt = """
Descrição:

"Uma montanha ao pôr do sol, céu en tons alaranjados, lua cheia grande,
um pai e um filho andando de bicicleta na montanha."
"""

response = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.6
)
print(f"Resposta {response.choices[0].message.content}\n")
# Out:
# Resposta ## 1. Significados simbólicos dos elementos
#
# | Elemento | Significado‐cultural / arquetípico | Possíveis leituras específicas no contexto da cena |
# |----------|-----------------------------------|----------------------------------------------------|
# | **Montanha** | • Elevação, desafio, permanência.<br>• “Lugar sagrado” nas mitologias (Monte Olympus, Monte Meru).<br>• Isolamento e contemplação. | • Representa um percurso de vida que exige esforço e superação. <br>• O “cume” pode ser visto como meta ou ponto de vista privilegiado que o pai quer mostrar ao filho. |
# | **Pôr do sol (céu alaranjado)** | • Transição, fim de ciclo, passagem do dia para a noite.<br>• Calor, conforto, nostalgia.<br>• Cores quentes associadas ao coração, ao afeto. | • Sugere um momento de “encerramento” do dia, mas também de “renovação” (o sol ainda está presente, embora se vá). <br>• O tom alaranjado cria uma atmosfera acolhedora que suaviza a dureza da montanha. |
# ...

# %% [markdown]
# ### Análise Comparativa

# %%
descricao_a = "A lua cheia"
descricao_b = "o Sol ao meio dia"

user_prompt = f"""
Compare estas duas descrições de imagens:
1. Diferença de cores e atmosfera
2. Elementos principais
3. Estilos possíveis
4. Emoções transmitidas

DESCRIÇÃO A: {descricao_a}
DESCRIÇÃO B: {descricao_b}
"""

response = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.6
)
print(f"Resposta {response.choices[0].message.content}\n")
# Out:
# Resposta ## Comparação semiótica entre **Descrição A – “A lua cheia”** e **Descrição B – “O Sol ao meio‑dia”**
#
# | Aspecto | **Descrição A – Lua cheia** | **Descrição B – Sol ao meio‑dia** |
# |---|---|---|
# | **1. Diferença de cores e atmosfera** | - **Paleta cromática:** tons de **prata, branco, azul‑escuro, cinza** e, em algumas representações, nuances de **amarelo pálido** ou **roxo**.<br>- **Atmosfera:** geral **noturna**, silenciosa, misteriosa; a luz é **difusa** e **reflexiva**, criando sombras suaves.<br>- **Contraste:** a lua ilumina contra um fundo escuro, gerando um **alto contraste** entre luz e sombra. | - **Paleta cromática:** predomínio de **amarelo, dourado, laranja, branco‑quente** e, em céu claro, **azul celeste**.<br>- **Atmosfera:** diurna, **aberta**, **vibrante**, com sensação de **clareza** e **energia**.<br>- **Contraste:** luz direta, sombras curtas e nítidas; o brilho do sol pode “lavar” as cores, reduzindo a saturação de tons mais escuros. |
# ...
